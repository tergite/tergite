# %%
import qiskit.circuit as circuit
from qiskit.providers.tergite import Tergite
from time import sleep
import requests

# %%
chalmers = Tergite.get_provider()
backend = chalmers.get_backend("OpenQASM")
backend.set_options(shots=1024)
backend
# Out:
# TergiteBackend object @ 0x7fa0d2ae73d0:
#   backend_name:               OpenQASM
#   backend_version:            2022.10.25
#   n_qubits:                   5
#   basis_gates:                []
#   gates:                      []
#   local:                      False
#   simulator:                  False
#   conditional:                False
#   open_pulse:                 False
#   memory:                     True
#   max_shots:                  inf
#   coupling_map:               [[0, 0], [1, 0], [2, 0], [3, 0], [4, 0]]
#   dynamic_reprate_enabled:    False
#   meas_levels:                (2,)
#   characterized:              False

# %%
qc = circuit.QuantumCircuit(2, 2)
qc.h(1)
qc.measure(1, 1)
qc.draw()
# Out:
#
# q_0: ────────
#      ┌───┐┌─┐
# q_1: ┤ H ├┤M├
#      └───┘└╥┘
# c_0: ══════╬═
#            ║
# c_1: ══════╩═

# %%
job = backend.run(qc)
# Out:
# Tergite: Job has been successfully submitted

# %%
sleep(10)
job.result()
# Out:
# Results OK
# Result(backend_name='OpenQASM', backend_version='2022.10.25', qobj_id='43a030fb-bb6f-406f-8b94-88c28aace778', job_id='a4ce432f-a344-4c7c-92a9-755be0d6456c', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x19': 31, '0x4': 29, '0x3': 44, '0xa': 40, '0xd': 34, '0x1c': 31, '0x7': 20, '0x15': 34, '0x18': 34, '0x16': 32, '0x1b': 39, '0xc': 38, '0x2': 34, '0x1d': 33, '0x5': 41, '0x1f': 25, '0x6': 31, '0x1': 21, '0xb': 34, '0x8': 38, '0x12': 26, '0xe': 36, '0x13': 35, '0x11': 38, '0x1a': 34, '0x14': 37, '0x10': 26, '0x0': 20, '0x9': 30, '0xf': 23, '0x1e': 32, '0x17': 24}, memory=['0x19', '0x4', '0x3', '0xa', '0xd', '0x1c', '0x7', '0x15', '0x3', '0x18', '0x16', '0x1b', '0xc', '0x2', '0x1d', '0x2', '0x15', '0x1d', '0x5', '0x1f', '0x6', '0x7', '0x1', '0x1d', '0xb', '0x8', '0x3', '0x12', '0x1c', '0x15', '0x19', '0xe', '0x1c', '0x1d', '0x13', '0x1b', '0x15', '0x18', '0xd', '0x18', '0x4', '0x8', '0x19', '0x16', '0x1', '0x5', '0x5', '0x11', '0x1a', '0xb', '0x11', '0xb', '0xa', '0xb', '0x2', '0xb', '0x1d', '0x14', '0x4', '0x14', '0x15', '0x19', '0x4', '0x18', '0xa', '0x1c', '0x11', '0x12', '0xc', '0x2', '0x19', '0x14', '0x6', '0xd', '0x16', '0x10', '0x3', '0x1b', '0x19', '0x1d', '0x0', '0x16', '0x8', '0x9', '0x4', '0x1b', '0x1a', '0x6', '0x1', '0x9', '0x19', '0x2', '0x18', '0x15', '0x9', '0xe', '0xa', '0x13', '0xe', '0x1d', '0x6', '0x1c', '0x4', '0xf', '0x1d', '0xb', '0x1', '0xa', '0x19', '0x8', '0x15', '0xb', '0x5', '0x5', '0xe', '0xf', '0x16', '0x1e', '0x2', '0xb', '0x11', '0x1b', '0x5', '0x10', '0x19', '0x16', '0x6', '0x17', '0x1c', '0x1c', '0x1d', '0xd', '0x