# %%
# %matplotlib inline
import qiskit.circuit as circuit
import qiskit.pulse as pulse
import matplotlib.pyplot as plt
import qiskit.compiler as compiler
import retworkx.visualization as rxv
import numpy as np
from tqdm.auto import tqdm
import json
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import rich
from qiskit.providers.tergite import Tergite
from qiskit import Aer
from qiskit.visualization.pulse_v2.stylesheet import IQXDebugging, IQXSimple
from qiskit_experiments.library.tomography import StateTomography

# %%
# from qiskit import *
from qiskit.ignis.verification.tomography import (
    state_tomography_circuits,
    StateTomographyFitter,
)
from qiskit.visualization import plot_state_city, plot_bloch_multivector
from qiskit.visualization import plot_state_paulivec, plot_state_hinton
from qiskit.visualization import plot_state_qsphere
import qiskit.quantum_info as qi
from qiskit.providers.tergite import Tergite
from qiskit.visualization import plot_histogram
from pprint import pprint
# Out:
# C:\Users\Axel\AppData\Local\Temp\ipykernel_8036\3378337631.py:2: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
#   from qiskit.ignis.verification.tomography import (

# %%
backend = Aer.get_backend("aer_simulator")

# %%
q = circuit.QuantumRegister(5)
circ = circuit.QuantumCircuit(q)
circ.barrier()
circ.reset([q[0]])

print("Input circuit")
print(circ)
# Out:
# Input circuit
#        ░
# q1_0: ─░──|0>─
#        ░
# q1_1: ─░──────
#        ░
# q1_2: ─░──────
#        ░
# q1_3: ─░──────
#        ░
# q1_4: ─░──────
#        ░

# %%
target_state = qi.Statevector.from_instruction(circ)

# %%
tomography_circuits = state_tomography_circuits(circ, [q[0]])

# %%
job = backend.run(tomography_circuits, meas_level=2)

# %%
rich.print(job.qobj())
# Out:
# QASM Qobj: 6a2a9cf7-7b76-440b-89e1-f87e1e971272:
# Config: {'batched_shots_gpu': True,
#  'batched_shots_gpu_max_qubits': 16,
#  'blocking_enable': False,
#  'chop_threshold': 1e-08,
#  'cuStateVec_enable': False,
#  'device': 'CPU',
#  'enable_truncation': True,
#  'extended_stabilizer_approximation_error': 0.05,
#  'extended_stabilizer_metropolis_mixing_time': 5000,
#  'extended_stabilizer_norm_estimation_repetitions': 3,
#  'extended_stabilizer_norm_estimation_samples': 100,
#  'extended_stabilizer_parallel_threshold': 100,
#  'extended_stabilizer_probabilities_snapshot_samples': 3000,
#  'extended_stabilizer_sampling_method': 'resampled_metropolis',
#  'fusion_enable': True,
#  'fusion_verbose': False,
#  'init_qubits': True,
#  'library_dir': 'C:\\Users\\Axel\\anaconda3\\envs\\qiskit\\lib\\site-packages\\qiskit_aer\\backends',
#  'matrix_product_state_truncation_threshold': 1e-16,
#  'meas_level': 2,
#  'memory': False,
#  'memory_slots': 1,
#  'method': 'automatic',
#  'mps_log_data': False,
#  'mps_omp_threads': 1,
#  'mps_parallel_threshold': 14,
#  'mps_sample_measure_algorithm': 'mps_heuristic',
#  'mps_swap_direction': 'mps_swap_left',
#  'n_qubits': 5,
#  'num_threads_per_device': 1,
#  'optypes': [{'HGate', 'Barrier', 'Gate', 'Measure', 'Reset', 'Instruction'},
#              {'Barrier',
#               'Gate',
#               'HGate',
#               'Instruction',
#               'Measure',
#               'Reset',
#               'SdgGate'},
#              {'Instruction', 'Barrier', 'Measure', 'Reset'}],
#  'parameter_binds': [],
#  'parametric_pulses': [],
#  'precision': 'double',
#  'shots': 1024,
#  'stabilizer_max_snapshot_probabilities': 32,
#  'statevector_parallel_threshold': 14,
#  'statevector_sample_measure_opt': 10,
#  'zero_threshold': 1e-10}
# Header: {'backend_name': 'aer_simulator', 'backend_version': '0.11.0'}
# Experiments:
#
# QASM Experiment:
# Header:
# {'clbit_labels': [['c1', 0]],
#  'creg_sizes': [['c1', 1]],
#  'global_phase': 0.0,
#  'memory_slots': 1,
#  'metadata': {},
#  'n_qubits': 5,
#  'name': "('X',)",
#  'qreg_sizes': [['q1', 5]],
#  'qubit_labels': [['q1', 0], ['q1', 1], ['q1', 2], ['q1', 3], ['q1', 4]]}
# Config:
# {'memory_slots': 1, 'n_qubits': 5}
#
#         Instruction: barrier
#                 qubits: [0, 1, 2, 3, 4]
#
#         Instruction: reset
#                 qubits: [0]
#
#         Instruction: barrier
#                 qubits: [0, 1, 2, 3, 4]
#
#         Instruction: h
#                 qubits: [0]
#
#         Instruction: measure
#                 qubits: [0]
#                 memory: [0]
#
#
# QASM Experiment:
# Header:
# {'clbit_labels': [['c1', 0]],
#  'creg_sizes': [['c1', 1]],
#  'global_phase': 0.0,
#  'memory_slots': 1,
#  'metadata': {},
#  'n_qubits': 5,
#  'name': "('Y',)",
#  'qreg_sizes': [['q1', 5]],
#  'qubit_labels': [['q1', 0], ['q1', 1], ['q1', 2], ['q1', 3], ['q1', 4]]}
# Config:
# {'memory_slots': 1, 'n_qubits': 5}
#
#         Instruction: barrier
#                 qubits: [0, 1, 2, 3, 4]
#
#         Instruction: reset
#                 qubits: [0]
#
#         Instruction: barrier
#                 qubits: [0, 1, 2, 3, 4]
#
#         Instruction: sdg
#                 qubits: [0]
#
#         Instruction: h
#                 qubits: [0]
#
#         Instruction: measure
#                 qubits: [0]
#                 memory: [0]
#
#
# QASM Experiment:
# Header:
# {'clbit_labels': [['c1', 0]],
#  'creg_sizes': [['c1', 1]],
#  'global_phase': 0.0,
#  'memory_slots': 1,
#  'metadata': {},
#  'n_qubits': 5,
#  'name': "('Z',)",
#  'qreg_sizes': [['q1', 5]],
#  'qubit_labels': [['q1', 0], ['q1', 1], ['q1', 2], ['q1', 3], ['q1', 4]]}
# Config:
# {'memory_slots': 1, 'n_qubits': 5}
#
#         Instruction: barrier
#                 qubits: [0, 1, 2, 3, 4]
#
#         Instruction: reset
#                 qubits: [0]
#
#         Instruction: barrier
#                 qubits: [0, 1, 2, 3, 4]
#
#         Instruction: measure
#                 qubits: [0]
#                 memory: [0]

# %%
rich.print(job.result().to_dict())
# Out:
# {
#     'backend_name': 'aer_simulator',
#     'backend_version': '0.11.0',
#     'date': '2022-10-31T13:10:05.016211',
#     'header': {'backend_name': 'aer_simulator', 'backend_version': '0.11.0'},
#     'qobj_id': '6a2a9cf7-7b76-440b-89e1-f87e1e971272',
#     'job_id': '0194566b-a642-4bb9-b8cb-3401d152089e',
#     'status': 'COMPLETED',
#     'success': True,
#     'results': [
#         {
#             'shots': 1024,
#             'success': True,
#             'data': {'counts': {'0x0': 516, '0x1': 508}},
#             'meas_level': <MeasLevel.CLASSIFIED: 2>,
#             'header': {
#                 'clbit_labels': [['c1', 0]],
#                 'creg_sizes': [['c1', 1]],
#                 'global_phase': 0.0,
#                 'memory_slots': 1,
#                 'metadata': {},
#                 'n_qubits': 5,
#                 'name': "('X',)",
#                 'qreg_sizes': [['q1', 5]],
#                 'qubit_labels': [['q1', 0], ['q1', 1], ['q1', 2], ['q1', 3], ['q1', 4]]
#             },
#             'status': 'DONE',
#             'seed_simulator': 756750332,
#             'metadata': {
#                 'batched_shots_optimization': False,
#                 'method': 'stabilizer',
#                 'active_input_qubits': [0],
#                 'device': 'CPU',
#                 'remapped_qubits': False,
#                 'num_qubits': 1,
#                 'num_clbits': 1,
#                 'input_qubit_map': [[0, 0]],
#                 'measure_sampling': False,
#                 'noise': 'ideal',
#                 'parallel_shots': 8,
#                 'parallel_state_update': 1,
#                 'fusion': {'enabled': False}
#             },
#             'time_taken': 0.0047482
#         },
#         {
#             'shots': 1024,
#             'success': True,
#             'data': {'counts': {'0x0': 516, '0x1': 508}},
#             'meas_level': <MeasLevel.CLASSIFIED: 2>,
#             'header': {
#                 'clbit_labels': [['c1', 0]],
#                 'creg_sizes': [['c1', 1]],
#                 'global_phase': 0.0,
#                 'memory_slots': 1,
#                 'metadata': {},
#                 'n_qubits': 5,
#                 'name': "('Y',)",
#                 'qreg_sizes': [['q1', 5]],
#                 'qubit_labels': [['q1', 0], ['q1', 1], ['q1', 2], ['q1', 3], ['q1', 4]]
#             },
#             'status': 'DONE',
#             'seed_simulator': 756752445,
#             'metadata': {
#                 'batched_shots_optimization': False,
#                 'method': 'stabilizer',
#                 'active_input_qubits': [0],
#                 'device': 'CPU',
#                 'remapped_qubits': False,
#                 'num_qubits': 1,
#                 'num_clbits': 1,
#                 'input_qubit_map': [[0, 0]],
#                 'measure_sampling': False,
#                 'noise': 'ideal',
#                 'parallel_shots': 8,
#                 'parallel_state_update': 1,
#                 'fusion': {'enabled': False}
#             },
#             'time_taken': 0.0027785
#         },
#         {
#             'shots': 1024,
#             'success': True,
#             'data': {'counts': {'0x0': 1024}},
#             'meas_level': <MeasLevel.CLASSIFIED: 2>,
#             'header': {
#                 'clbit_labels': [['c1', 0]],
#                 'creg_sizes': [['c1', 1]],
#                 'global_phase': 0.0,
#                 'memory_slots': 1,
#                 'metadata': {},
#                 'n_qubits': 5,
#                 'name': "('Z',)",
#                 'qreg_sizes': [['q1', 5]],
#                 'qubit_labels': [['q1', 0], ['q1', 1], ['q1', 2], ['q1', 3], ['q1', 4]]
#             },
#             'status': 'DONE',
#             'seed_simulator': 756754558,
#             'metadata': {
#                 'batched_shots_optimization': False,
#                 'method': 'stabilizer',
#                 'active_input_qubits': [0],
#                 'device': 'CPU',
#                 'remapped_qubits': False,
#                 'num_qubits': 1,
#                 'num_clbits': 1,
#                 'input_qubit_map': [[0, 0]],
#                 'measure_sampling': False,
#                 'noise': 'ideal',
#                 'parallel_shots': 8,
#                 'parallel_state_update': 1,
#                 'fusion': {'enabled': False}
#             },
#             'time_taken': 0.001631
#         }
#     ],
#     'metadata': {
#         'parallel_experiments': 1,
#         'omp_enabled': True,
#         'max_memory_mb': 65413,
#         'max_gpu_memory_mb': 0,
#         'num_processes_per_experiments': 1,
#         'time_taken_load_qobj': 0.0004934,
#         'mpi_rank': 0,
#         'num_mpi_processes': 1,
#         'time_taken_execute': 0.0095534,
#         'time_taken': 0.0100635
#     },
#     'time_taken': 0.011984109878540039
# }

# %%
fitter = StateTomographyFitter(job.result(), tomography_circuits)

# %%
fitter.data
# Out:
# {('X',): {'0': 516, '1': 508},
#  ('Y',): {'0': 516, '1': 508},
#  ('Z',): {'0': 1024}}

# %%
density_matrix = fitter.fit(method="lstsq")

# %%
fig = plot_bloch_multivector(
    density_matrix, reverse_bits=True, filename="bg_bloch_multivector.jpg"
)

# %%
fig

# %%
def frame_bloch(j):
    J = np.linspace(0, 1.2 * np.pi / 2, 10)
    q = circuit.QuantumRegister(5)
    circ = circuit.QuantumCircuit(q)
    [circ.reset(qb) for qb in q]  # reset qubits

    circ.ry(J[j], q[4])  # ry <-

    circ.rx(np.pi / 4, q[3]), circ.rz(J[j], q[3])  # rz <-

    circ.rx(J[j], q[2])  # rx

    circ.rx(-np.pi / 4, q[1]), circ.rz(-J[j], q[1])  # rz ->

    circ.ry(-J[j], q[0])  # ry ->

    tomography_circuits = state_tomography_circuits(circ, q)
    job = backend.run(tomography_circuits, meas_level=2)
    fitter = StateTomographyFitter(job.result(), tomography_circuits)
    density_matrix = fitter.fit(method="lstsq")
    plot_bloch_multivector(
        density_matrix, reverse_bits=True, filename=f"frames/frame{j}.jpg"
    )


[frame_bloch(j) for j in tqdm(range(10))]
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# [None, None, None, None, None, None, None, None, None, None]
